# %% [markdown]
# # Predictive Analytics Challenge
# ***
#
# Hathaway Zhang <br>
# 104369396 <br>
# Nov.4, 2018
# ***

# %% [markdown]
# For this predictive analytics challenge, I utilized `sklearn` along with the [Brandzooka Advertising Performance Data Set](https://brandzooka.com/) to build a machine learning algorithm that predicts the advertising effectiveness --- `totalClicks` in my case. This predictive algorithm is able to show which feature will drive the clicks most and what I can do to improve my Google’s Online Marketing Challenge. The  R2  will be provided to analysis the performance of the machine learning algorithm. Moreover, significant impact factors will be analyzed according to the coefficient weights.
#
# __<font color=red>! It may take times to run this script !</font>__

# %% [markdown]
# ### Part One: Data Cleaning & Preparing
# ***
# Import necessary package for this project <br>
# All the models are selected from [`sklearn`](https://scikit-learn.org/stable/supervised_learning.html#supervised-learning). And these models include:
#    - LassoLarsCV
#    - LarsCV
#    - RidgeCV
#    - ElasticNetCV
#    - OrthogonalMatchingPursuitCV

# %%
import pandas as pd
import pandas
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LassoLarsCV
from sklearn.linear_model import LarsCV
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import OrthogonalMatchingPursuitCV

# %% [markdown]
# Read in the raw dataset then exclude invalid predictors from the raw data except `totalClicks`. Also goes over the columns to double check if I've selected proper predictors. To improve the performance of prediction. I will also remove duplicates, missing information, and extraneous features to clean the data set at the first stage.
# Delete columns with missing information and duplicates values.

# %%
Sheet = pd.ExcelFile("campaign data_only matching videos.xlsx")
# print(Sheet.sheet_names)
dfRaw = Sheet.parse('dataforboone')

# %%
list(dfRaw)
## Exclude invalid predictors from the raw data except 'totalClicks'
dfC = dfRaw.drop(columns=['bidWinRate', 'campaignCompletedEmailSent', 'campaignStartedEmailSent',  
                           'clickThroughRate', 'completionRate',  'completionRate',  'couponCode',
                           'discount', 'emailSent', 'ourMarkupFee', 'spentBudget', 'status', 'tdCampaignId', 'total',
                           'totalImpressions', 'updatedAt',  'viewability', 'totalClicks'])

# Get an overview about all the columns
dfC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 53 columns):
# id                           6 non-null object
# adLandingPage                148 non-null object
# adLanguage                   0 non-null float64
# audienceGender               148 non-null object
# audienceInterests            126 non-null object
# audienceLocationCountry      22 non-null object
# audienceLocationCountries    119 non-null object
# audienceLocationRegions      56 non-null object
# audienceLocationZipcodes     139 non-null object
# audienceMaxAge               148 non-null int64
# audienceMinAge               148 non-null int64
# audiencePlacements           146 non-null object
# budget                       148 non-null int64
# createdAt                    148 non-null object
# goal                         145 non-null object
# hours                        75 non-null object
# targetingCost                148 non-null int64
# targetingPercent             148 non-null float64
# placementCost                148 non-null int64
# ourTargetingPercent          148 non-null float64
# projectedImpressions         148 non-null int64
# scheduleDateFrom             148 non-null datetime64[ns]
# scheduleDateTo               56 non-null datetime64[ns]
# title                        148 non-null object
# userId                       148 non-null object
# videoId                      148 non-null object
# callToAction                 148 non-null int64
# quality                      148 non-null int64
# keywords                     148 non-null int64
# contact                      148 non-null int64
# CEO                          148 non-null int64
# beautifulFigure              148 non-null int64
# celebrity                    148 non-null int64
# targetedStarring             148 non-null int64
# animated                     148 non-null int64
# bright_colorful              148 non-null int64
# logoInvolved                 148 non-null int64
# mimicUI                      148 non-null int64
# shocking                     148 non-null int64
# bgmQuality                   148 non-null int64
# eyeCatchingTarget            148 non-null int64
# conversation                 148 non-null int64
# wordy                        148 non-null int64
# narratage                    148 non-null int64
# textOnly                     148 non-null int64
# eympathy                     148 non-null int64
# humor                        148 non-null int64
# introduce                    148 non-null int64
# accent                       148 non-null int64
# suspense                     148 non-null int64
# guarantee                    148 non-null int64
# diversity                    148 non-null int64
# category                     148 non-null object
# dtypes: datetime64[ns](2), float64(3), int64(32), object(16)
# memory usage: 61.4+ KB

# %%
## To improve the performance of prediction. I will remove duplicates, missing information, 
## and extraneous features to clean the data set at the first stage.
## Delete columns with missing information and duplicates values
dfClean = dfC.drop(columns=['id','adLanguage','audienceLocationRegions','audienceLocationZipcodes',
                            'hours'])

# %% [markdown]
# For a better performance, I will convert those object columns into dummy table. In this way, categorical variables are converted into integer data and the machine learning algorithm will do a better job in prediction. `create_dummy` function is aimed to converted categorical data. I haven't applied this function to `audienceLocationCountry` as this segement contains empty rows and inconsistent country name.

# %%
dfClean['audienceLocationCountry'] = dfClean['audienceLocationCountry'].astype(str)
dfClean['audienceLocationCountries'] = dfClean['audienceLocationCountries'].astype(str)
dfClean['audienceLocationCountries'] = dfClean['audienceLocationCountries'].apply(lambda x: x.replace('\"',''))
dfClean['audienceLocationCountries'] = dfClean['audienceLocationCountries'].apply(lambda x: x.replace('[',''))
dfClean['audienceLocationCountries'] = dfClean['audienceLocationCountries'].apply(lambda x: x.replace(']',''))

new_col = dfClean[['audienceLocationCountry', 'audienceLocationCountries']].apply(lambda x: ','.join(x), axis=1)
new_col = new_col.apply(lambda x: x.replace('nan,',''))
new_col = new_col.apply(lambda x: x.replace(',nan',''))
new_col = new_col.apply(lambda x: x.replace('United States','USA'))

# %%
## Combine audienceLocationCountry and audienceLocationCountries into a new column, then drop
## these columns
dfClean.insert(loc=3, column='audienceLocation', value=new_col)
dfClean.insert(loc=0, column='totalClicks', value=dfRaw['totalClicks'])
dfClean = dfClean.drop(columns=['audienceLocationCountry','audienceLocationCountries'])
dfLC = dfClean['audienceLocation'].str.get_dummies(sep=',')
dfClean = pd.concat([dfClean, dfLC], axis=1)

# %%
def create_dummy(pre):
    global dfClean
    dfClean[pre] = dfClean[pre].astype(str)
    dfClean[pre] = dfClean[pre].apply(lambda x: x.replace('\"',''))
    dfClean[pre] = dfClean[pre].apply(lambda x: x.replace('[',''))
    dfClean[pre] = dfClean[pre].apply(lambda x: x.replace(']',''))
    # convert interests into dummy table format
    dfConvert = dfClean[pre].str.get_dummies(sep=',')
    dfClean = pd.concat([dfClean, dfConvert], axis=1)

# %%
list_pre = ['audienceGender','audienceInterests','audiencePlacements','goal','category']
for i in list_pre:
    create_dummy(i)

# %%
## RangeIndex: 148 entries, 0 to 147
## Columns: 362 entries, totalClicks to viewability
## dtypes: datetime64[ns](2), float64(2), int64(347), object(11)
dfClean = dfClean.dropna(axis=1, how='all')
dfClean = dfClean.drop(columns=['nan','audienceGender','audienceLocation','audienceInterests','audiencePlacements','goal',
                                'createdAt','scheduleDateFrom','scheduleDateTo','title','category','userId','videoId','adLandingPage'])
dfClean.info()
dfClean.to_csv("campaign.csv", sep=',')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Columns: 378 entries, totalClicks to ytv
# dtypes: float64(2), int64(376)
# memory usage: 437.1 KB

# %%
## Double check if null sets are still exist
# dfClean.select_dtypes(include=['object'])

# %% [markdown]
# ### Part Two: Machine Learning Algorithm

# %% [markdown]
# After cleaning the dataset to make sure it could have proper performance, I started training and predicting the data set through multiple machine learning algorithm. To start learning, I set `totalClicks` as target and put all the predictors I've cleaned into `predictors`. For all these model, I will train 70% of the data and test the rest 30% of data. Since every prediction is created randomly, I simulated the prediction for 10000 or 20000 times to obtain the optimal r-squred result.

# %%
# create a list of all the predictors you're going to feed into the LassoLarsCV model
allvariablenames = list(dfClean.columns.values)
listofallpredictors = allvariablenames[1:]
#load predictors into dataframe
predictors = dfClean[listofallpredictors]  
#load target into dataframe
target = dfClean['totalClicks']

# %% [markdown]
# #### LassoLarsCV
# ***
# **LassoLars** is a lasso model implemented using the LARS algorithm, and unlike the implementation based on coordinate_descent, this yields the exact solution, which is piecewise linear as a function of the norm of its coefficients.

# %%
def max_r_squared(n):
    rsquared_train = []
    rsquared_test = []
    coeff = []
    # find the maximum r-squared value and corresponding random_state value
    for i in range(n):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=i)
        model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
        
        rsquared_train.append(model.score(pred_train,tar_train))
        rsquared_test.append(model.score(pred_test,tar_test))
        mx = rsquared_test.index(max(rsquared_test))
    
    # put the maximum random_state value back into the model and display the coefficients
    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=mx)
    model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
    predictors_model=pd.DataFrame(listofallpredictors)
    predictors_model.columns = ['label']
    predictors_model['coeff'] = model.coef_
    for index, row in predictors_model.iterrows():
        if row['coeff'] > 0:
            coeff.append(row.values)
    
    return rsquared_train[mx], rsquared_test[mx], coeff, mx, model.intercept_

# %%
max_r_squared(10000)
# Out:
# (0.4065024567596378,
#  0.9774456730304493,
#  [array(['budget', 0.08631671489574987], dtype=object)],
#  6763,
#  76.65804019375742)

# %% [markdown]
# This model provides the best $r^2$ so far. Identified the top 3, 10, and 40 r-squared values to check if the coefficient would only contain budget.

# %%
def max_r_squared_top_3(n):
    rsquared_train = []
    rsquared_test = []
    coeff = []
    train = []
    test = []
    # find the top three r-squared values and their corresponding random_state values
    for i in range(n):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=i)
        model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
        
        rsquared_train.append(model.score(pred_train,tar_train))
        rsquared_test.append(model.score(pred_test,tar_test)) 
        mx = sorted(range(len(rsquared_test)), key=lambda i: rsquared_test[i], reverse=True)[:3]
    
    for j in range(3):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=mx[j])
        model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
        train.append(rsquared_train[mx[j]])
        test.append(rsquared_test[mx[j]])
        predictors_model=pd.DataFrame(listofallpredictors)
        predictors_model.columns = ['label']
        predictors_model['coeff'] = model.coef_
        for index, row in predictors_model.iterrows():
            if row['coeff'] > 0:
                coeff.append(row.values)
    
    return train, test, mx, coeff

# %%
max_r_squared_top_3(10000)
# Out:
# ([0.4065024567596378, 0.4217922728245661, 0.42712435329085485],
#  [0.9774456730304493, 0.9712468614497402, 0.9699994676190249],
#  [6763, 8456, 3486],
#  [array(['budget', 0.08631671489574987], dtype=object),
#   array(['budget', 0.08860510821364571], dtype=object),
#   array(['budget', 0.08018047648837662], dtype=object),
#   array(['targetingCost', 0.01810776856736746], dtype=object)])

# %%
def max_r_squared_top_10(n):
    rsquared_train = []
    rsquared_test = []
    coeff = []
    train = []
    test = []
    # find the top ten r-squared values and their corresponding random_state values
    for i in range(n):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=i)
        model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
        
        rsquared_train.append(model.score(pred_train,tar_train))
        rsquared_test.append(model.score(pred_test,tar_test)) 
        mx = sorted(range(len(rsquared_test)), key=lambda i: rsquared_test[i], reverse=True)[:10]
    
    for j in range(10):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=mx[j])
        model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
        train.append(rsquared_train[mx[j]])
        test.append(rsquared_test[mx[j]])
        # load predictors into predictors_model
        predictors_model=pd.DataFrame(listofallpredictors)
        # rename header of predictors_model as 'label'
        predictors_model.columns = ['label']
        # create a column named coeff and add coeff. to dataframe
        predictors_model['coeff'] = model.coef_
        for index, row in predictors_model.iterrows():
        # since any coefficients that are non-zero are significant, find all the coeff, greater than 0
            if row['coeff'] > 0:
                # print out the significant values
                coeff.append(row.values)
    
    return train, test, mx, coeff

# %%
max_r_squared_top_10(10000)
# Out:
# ([0.4065024567596378,
#   0.4217922728245661,
#   0.42712435329085485,
#   0.40531647396192794,
#   0.37631727886847677,
#   0.3562131062112781,
#   0.39502931234023436,
#   0.4066399781506745,
#   0.4214674186775904,
#   0.4292206466363122],
#  [0.9774456730304493,
#   0.9712468614497402,
#   0.9699994676190249,
#   0.9676155045101624,
#   0.9662396218010796,
#   0.9634843534728885,
#   0.963179830115318,
#   0.9630004844677185,
#   0.9626532756473132,
#   0.9618035967390384],
#  [6763, 8456, 3486, 8278, 95, 5377, 2661, 103, 6292, 3502],
#  [array(['budget', 0.08631671489574987], dtype=object),
#   array(['budget', 0.08860510821364571], dtype=object),
#   array(['budget', 0.08018047648837662], dtype=object),
#   array(['targetingCost', 0.01810776856736746], dtype=object),
#   array(['budget', 0.08641743073508373], dtype=object),
#   array(['targetingCost', 0.0018100487980428975], dtype=object),
#   array(['budget', 0.07672520612523405], dtype=object),
#   array(['placementCost', 0.02945518047734132], dtype=object),
#   array(['budget', 0.08588058703650478], dtype=object),
#   array(['budget', 0.08086048458878484], dtype=object),
#   array(['targetingCost', 0.012481737216113167], dtype=object),
#   array(['budget', 0.08177897697208827], dtype=object),
#   array(['targetingCost', 0.007413401375255569], dtype=object),
#   array(['budget', 0.06172728226120375], dtype=object),
#   array(['targetingCost', 0.048414878632452654], dtype=object),
#   array(['budget', 0.08934203206917163], dtype=object)])

# %%
def max_r_squared_top_40(n):
    rsquared_train = []
    rsquared_test = []
    coeff = []
    train = []
    test = []
    # find the top 40 r-squared values and their corresponding random_state values
    for i in range(n):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=i)
        model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
        
        rsquared_train.append(model.score(pred_train,tar_train))
        rsquared_test.append(model.score(pred_test,tar_test)) 
        mx = sorted(range(len(rsquared_test)), key=lambda i: rsquared_test[i], reverse=True)[:40]
    
    for j in range(40):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=mx[j])
        model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
        train.append(rsquared_train[mx[j]])
        test.append(rsquared_test[mx[j]])
        predictors_model=pd.DataFrame(listofallpredictors)
        predictors_model.columns = ['label']
        predictors_model['coeff'] = model.coef_
        for index, row in predictors_model.iterrows():
            if row['coeff'] > 0:
                coeff.append(row.values)
    
    return train, test, mx, coeff

# %%
max_r_squared_top_40(10000)
# Out:
# ([0.4065024567596378,
#   0.4217922728245661,
#   0.42712435329085485,
#   0.40531647396192794,
#   0.37631727886847677,
#   0.3562131062112781,
#   0.39502931234023436,
#   0.4066399781506745,
#   0.4214674186775904,
#   0.4292206466363122,
#   0.3444616283190496,
#   0.4047537222165852,
#   0.42934089362202266,
#   0.39476252610091,
#   0.40152692283436175,
#   0.4178805126782799,
#   0.4323132718495563,
#   0.4088220924712632,
#   0.40839134921222237,
#   0.38528303343888604,
#   0.4507849399544204,
#   0.42259284386473256,
#   0.43399881197783136,
#   0.4054898097318287,
#   0.4513773697059265,
#   0.3937651825484262,
#   0.4516777378587613,
#   0.43710335451783794,
#   0.39232217701925776,
#   0.44293401185824754,
#   0.4348772122742998,
#   0.42476356960879513,
#   0.4442232973360697,
#   0.4053162356824609,
#   0.4139531884441301,
#   0.43195170517421233,
#   0.37416250364034076,
#   0.43156448659260066,
#   0.43615758420583794,
#   0.4410652725715368],
#  [0.9774456730304493,
#   0.9712468614497402,
#   0.9699994676190249,
#   0.9676155045101624,
#   0.9662396218010796,
#   0.9634843534728885,
#   0.963179830115318,
#   0.9630004844677185,
#   0.9626532756473132,
#   0.9618035967390384,
#   0.9617818308158831,
#   0.9609285383765822,
#   0.9606914994303835,
#   0.9601754781731934,
#   0.9596353114512609,
#   0.9585414509549672,
#   0.9583755561353227,
#   0.9574066881703045,
#   0.956891110196573,
#   0.9566781987590494,
#   0.9562980532049141,
#   0.9561322275903912,
#   0.9558920926839575,
#   0.9558582822169062,
#   0.9551283975606537,
#   0.954079225726315,
#   0.9539791101469005,
#   0.9533203229210048,
#   0.9515807364038259,
#   0.9512128810508855,
#   0.9510680123224536,
#   0.9508716509374101,
#   0.9507465437685969,
#   0.9507205038879294,
#   0.9499829976451375,
#   0.9499731256280384,
#   0.949470437286016,
#   0.9492291442033629,
#   0.9485197723123229,
#   0.9483425413177665],
#  [6763,
#   8456,
#   3486,
#   8278,
#   95,
#   5377,
#   2661,
#   103,
#   6292,
#   3502,
#   4456,
#   2216,
#   4071,
#   6639,
#   2876,
#   7923,
#   1134,
#   3984,
#   9538,
#   1599,
#   6647,
#   1873,
#   7075,
#   1993,
#   6765,
#   5223,
#   8214,
#   5837,
#   3297,
#   4893,
#   776,
#   1132,
#   2243,
#   1189,
#   2130,
#   6950,
#   3745,
#   4258,
#   8858,
#   1121],
#  [array(['budget', 0.08631671489574987], dtype=object),
#   array(['budget', 0.08860510821364571], dtype=object),
#   array(['budget', 0.08018047648837662], dtype=object),
#   array(['targetingCost', 0.01810776856736746], dtype=object),
#   array(['budget', 0.08641743073508373], dtype=object),
#   array(['targetingCost', 0.0018100487980428975], dtype=object),
#   array(['budget', 0.07672520612523405], dtype=object),
#   array(['placementCost', 0.02945518047734132], dtype=object),
#   array(['budget', 0.08588058703650478], dtype=object),
#   array(['budget', 0.08086048458878484], dtype=object),
#   array(['targetingCost', 0.012481737216113167], dtype=object),
#   array(['budget', 0.08177897697208827], dtype=object),
#   array(['targetingCost', 0.007413401375255569], dtype=object),
#   array(['budget', 0.06172728226120375], dtype=object),
#   array(['targetingCost', 0.048414878632452654], dtype=object),
#   array(['budget', 0.08934203206917163], dtype=object),
#   array(['budget', 0.05221125362434428], dtype=object),
#   array(['targetingCost', 0.050392347125863456], dtype=object),
#   array(['budget', 0.08041650005390961], dtype=object),
#   array(['targetingCost', 0.007142037488853668], dtype=object),
#   array(['budget', 0.06961301622567578], dtype=object),
#   array(['placementCost', 0.08292856798515112], dtype=object),
#   array(['budget', 0.06911062204964082], dtype=object),
#   array(['targetingCost', 0.024507210168451928], dtype=object),
#   array(['budget', 0.08597995419462122], dtype=object),
#   array(['budget', 0.08892472437366411], dtype=object),
#   array(['budget', 0.09103801762383412], dtype=object),
#   array(['targetingCost', 0.008109688064778221], dtype=object),
#   array(['budget', 0.08702381142182254], dtype=object),
#   array(['budget', 0.09216213296508223], dtype=object),
#   array(['budget', 0.0764868681064313], dtype=object),
#   array(['targetingCost', 0.0012489534346233951], dtype=object),
#   array(['budget', 0.09183722136202065], dtype=object),
#   array(['budget', 0.08242016685363633], dtype=object),
#   array(['placementCost', 0.035546993532070505], dtype=object),
#   array(['budget', 0.09776496336909701], dtype=object),
#   array(['budget', 0.07694979833333777], dtype=object),
#   array(['targetingCost', 0.033565503916046346], dtype=object),
#   array(['budget', 0.08244227923441176], dtype=object),
#   array(['targetingCost', 0.02294925540472696], dtype=object),
#   array(['budget', 0.07834018976013055], dtype=object),
#   array(['targetingCost', 0.000358017528829906], dtype=object),
#   array(['budget', 0.09229484169508824], dtype=object),
#   array(['targetingCost', 0.00807674520662174], dtype=object),
#   array(['budget', 0.08797001899991681], dtype=object),
#   array(['targetingCost', 0.005592509597779746], dtype=object),
#   array(['budget', 0.08806957226831996], dtype=object),
#   array(['budget', 0.0902952996842033], dtype=object),
#   array(['targetingCost', 0.0029934445871770336], dtype=object),
#   array(['budget', 0.08806686146307938], dtype=object),
#   array(['targetingCost', 0.010291318689552385], dtype=object),
#   array(['budget', 0.07441997604663839], dtype=object),
#   array(['targetingCost', 0.04017920674862065], dtype=object),
#   array(['budget', 0.07888392830436604], dtype=object),
#   array(['targetingCost', 0.02998578107530491], dtype=object),
#   array(['budget', 0.09645082600985881], dtype=object),
#   array(['budget', 0.08852360334634335], dtype=object),
#   array(['budget', 0.07409488681390543], dtype=object),
#   array(['targetingCost', 0.03255330856776921], dtype=object),
#   array(['budget', 0.07194811284765207], dtype=object),
#   array(['targetingCost', 0.009030916832553965], dtype=object),
#   array(['budget', 0.07193385449458121], dtype=object),
#   array(['targetingCost', 0.04066002234257828], dtype=object),
#   array(['budget', 0.09653307500537339], dtype=object),
#   array(['budget', 0.08253413743854408], dtype=object),
#   array(['targetingCost', 0.011962129159557824], dtype=object)])

# %% [markdown]
# Instead of find the maximum r-squared value of testing data, finding the maximum sum of r-squared for testing and training data.

# %%
def max_r_squared_sum(n):
    global dfSum
    rsquared_train = []
    rsquared_test = []
    dfSum = pd.DataFrame(allvariablenames[1:])
    coeff = []
    # find the maximum sum of r-squared values and its corresponding random_state value
    for i in range(n):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=i)
        model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
        dfSum["coefficient{0}".format(i)] = model.coef_
        rsquared_train.append(model.score(pred_train,tar_train))
        rsquared_test.append(model.score(pred_test,tar_test))
        rsquared= [x + y for x, y in zip(rsquared_train, rsquared_test)]
        mx = rsquared.index(max(rsquared))
        
    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=mx)
    model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
    predictors_model=pd.DataFrame(listofallpredictors)
    predictors_model.columns = ['label']
    predictors_model['coeff'] = model.coef_
    for index, row in predictors_model.iterrows():
        if row['coeff'] != 0:
            coeff.append(row.values)
    
    return rsquared_train[mx], rsquared_test[mx], coeff, mx, model.intercept_

# %%
max_r_squared_sum(20000)
# Out:
# (0.9179901194905821,
#  0.8301898639433808,
#  [array(['budget', 0.07119603642235801], dtype=object),
#   array(['placementCost', 0.09444803778204203], dtype=object),
#   array(['callToAction', 9.626485225266828], dtype=object),
#   array(['contact', -10.334857639464932], dtype=object),
#   array(['beautifulFigure', 9.369398016382434], dtype=object),
#   array(['celebrity', -22.988016259901347], dtype=object),
#   array(['targetedStarring', 12.390903673160278], dtype=object),
#   array(['bright_colorful', -7.898632531003881], dtype=object),
#   array(['logoInvolved', 2.303066954475899], dtype=object),
#   array(['mimicUI', 6.247707849309872], dtype=object),
#   array(['bgmQuality', 4.836739779197172], dtype=object),
#   array(['conversation', -8.421379160693306], dtype=object),
#   array(['narratage', 15.967857234584145], dtype=object),
#   array(['humor', -0.12216904336451291], dtype=object),
#   array(['accent', -22.077896042300672], dtype=object),
#   array(['diversity', -5.2524113016751715], dtype=object),
#   array(['Canada', -7.654172122464005], dtype=object),
#   array(['Mexico', -17.0575115498175], dtype=object),
#   array(['Spain', 5.862065629022741], dtype=object),
#   array(['United Kingdom', 62.449571949761676], dtype=object),
#   array(['000+', -6.196125760576196], dtype=object),
#   array(['000-$374', 103.53626358867224], dtype=object),
#   array(['25', 7.40689128096016], dtype=object),
#   array(['African American', 103.14381419129336], dtype=object),
#   array(['Autos', -0.9975887552438365], dtype=object),
#   array(['Beverages', 15.618982777687517], dtype=object),
#   array(['Blue Collar', -17.793453294025692], dtype=object),
#   array(['Boating', 16.87405581904297], dtype=object),
#   array(['Brands', -13.639602699553887], dtype=object),
#   array(['Business Education', -10.477204731487154], dtype=object),
#   array(['Charity & Philanthropy', 84.22131881320414], dtype=object),
#   array(['DIY', 82.60469345988231], dtype=object),
#   array(['Events', -104.66789770419494], dtype=object),
#   array(['Fashion & Style', 0.5182547881536103], dtype=object),
#   array(['Finance', 8.886506357544256], dtype=object),
#   array(['Government', 0.7953289590520277], dtype=object),
#   array(['In Market for', -3.396007198624751], dtype=object),
#   array(['Industry', -12.799683919018388], dtype=object),
#   array(['Marital Status', -16.999424730923113], dtype=object),
#   array(['Online Activity', 24.079636549750894], dtype=object),
#   array(['Pets & Animals', 17.84362248486031], dtype=object),
#   array(['Real Estate', 59.610672039597205], dtype=object),
#   array(['Retail', -1.1845157391601848], dtype=object),
#   array(['Services', -50.09277745538044], dtype=object),
#   array(['CTR', 4.023737254656212], dtype=object),
#   array(['viewability', -0.18511777003216634], dtype=object),
#   array(['awareness', 48.27935374022981], dtype=object),
#   array(['doctor', 146.44789867939096], dtype=object),
#   array(['food', 22.940951806059797], dtype=object),
#   array(['liquid', -12.749783502551056], dtype=object),
#   array(['price', -11.482785849112462], dtype=object),
#   array(['sport', 69.90401775516297], dtype=object)],
#  1984,
#  9.588426659560895)

# %% [markdown]
# For LassoLars model, the best testing $r^2$ is around 0.83. Identifying the top 20 factors.

# %%
## Count the occurrence
dfSum['count'] = dfSum.astype(bool).sum(axis=1)
dfSum = dfSum.sort_values(by=['count'],ascending=False)
## Rank the factors
dfSum['rank'] = dfSum['count'].rank(ascending=False)
Result1 = dfSum[[0,'count','rank']]
Result1.head(20)
# Out:
#                           0  count  rank
# 2                    budget  16508   1.0
# 5             placementCost  14894   2.0
# 142  Charity & Philanthropy   7278   3.0
# 3             targetingCost   3478   4.0
# 168                     DIY   2660   5.0
# 293             Real Estate   2655   6.0
# 74                 000-$374   2631   7.0
# 359                  doctor   2189   8.0
# 322           Undergraduate   2150   9.0
# 345                   reach   2088  10.0

# %%
Result2 = dfSum[[0,'coefficient1984']].sort_values(by=['coefficient1984'],ascending=False)
Result2
# Out:
#                           0  coefficient1984
# 359                  doctor       146.447899
# 74                 000-$374       103.536264
# 111        African American       103.143814
# 142  Charity & Philanthropy        84.221319
# 168                     DIY        82.604693
# 371                   sport        69.904018
# 55           United Kingdom        62.449572
# 293             Real Estate        59.610672
# 351               awareness        48.279354
# 275         Online Activity        24.079637
# 361                    food        22.940952
# 286          Pets & Animals        17.843622
# 129                 Boating        16.874056
# 25                narratage        15.967857
# 126               Beverages        15.618983
# 15         targetedStarring        12.390904
# 8              callToAction         9.626485
# 13          beautifulFigure         9.369398
# 188                 Finance         8.886506
# 91                       25         7.406891
# 19                  mimicUI         6.247708
# 50                    Spain         5.862066
# 21               bgmQuality         4.836740
# 344                     CTR         4.023737
# 18             logoInvolved         2.303067
# 202              Government         0.795329
# 187         Fashion & Style         0.518255
# 5             placementCost         0.094448
# 2                    budget         0.071196
# 299                 Retired         0.000000
# ..                      ...              ...
# 342                  mobile         0.000000
# 210          Healthy Living         0.000000
# 370                 service         0.000000
# 183             Ethnicities         0.000000
# 147                 College         0.000000
# 298       Retail & Shopping         0.000000
# 143   Children in Household         0.000000
# 28                    humor        -0.122169
# 346             viewability        -0.185118
# 122                   Autos        -0.997589
# 297                  Retail        -1.184516
# 231           In Market for        -3.396007
# 33                diversity        -5.252411
# 71                     000+        -6.196126
# 35                   Canada        -7.654172
# 17          bright_colorful        -7.898633
# 23             conversation        -8.421379
# 11                  contact       -10.334858
# 136      Business Education       -10.477205
# 364                   price       -11.482786
# 362                  liquid       -12.749784
# 234                Industry       -12.799684
# 132                  Brands       -13.639603
# 255          Marital Status       -16.999425
# 43                   Mexico       -17.057512
# 128             Blue Collar       -17.793453
# 30                   accent       -22.077896
# 14                celebrity       -22.988016
# 303                Services       -50.092777
# 184                  Events      -104.667898
#
# [377 rows x 2 columns]

# %% [markdown]
# #### LarsCV
# ***
# Cross-validated Least Angle Regression model

# %%
def max_r_squared_Lars(n):
    rsquared_train = []
    rsquared_test = []
    coeff = []
    # find the maximum r-squared value and corresponding random_state value
    for i in range(n):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=i)
        model = LarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
        
        rsquared_train.append(model.score(pred_train,tar_train))
        rsquared_test.append(model.score(pred_test,tar_test))
        mx = rsquared_test.index(max(rsquared_test))
        
    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=mx)
    model = LassoLarsCV(cv=5, precompute=False).fit(pred_train, tar_train)
    # load predictors into predictors_model
    predictors_model=pd.DataFrame(listofallpredictors)
    # rename header of predictors_model as 'label'
    predictors_model.columns = ['label']
    # create a column named coeff and add coeff. to dataframe
    predictors_model['coeff'] = model.coef_
    for index, row in predictors_model.iterrows():
    # since any coefficients that are non-zero are significant, find all the coeff, greater than 0
        if row['coeff'] > 0:
            # print out the significant values
            coeff.append(row.values)
    
    return rsquared_train[mx], rsquared_test[mx], coeff, mx, model.intercept_

# %%
max_r_squared_Lars(10)
# Out:
# (0.4018562622516678,
#  0.8620038126251974,
#  [array(['budget', 0.1222922977225194], dtype=object),
#   array(['wordy', 7.129278270811197], dtype=object),
#   array(['narratage', 4.214814303269835], dtype=object),
#   array(['000-$374', 41.186177671948414], dtype=object),
#   array(['Charity & Philanthropy', 79.24999811876575], dtype=object),
#   array(['Cosmetic Surgery', 5.255254515126166], dtype=object),
#   array(['DIY', 49.71777960444509], dtype=object),
#   array(['Online Activity', 12.577870634407152], dtype=object),
#   array(['Pets & Animals', 15.482757794955857], dtype=object),
#   array(['Real Estate', 52.342493698115376], dtype=object),
#   array(['SEO', 0.26633038738390163], dtype=object),
#   array(['awareness', 23.56650935878031], dtype=object),
#   array(['doctor', 73.77608895204311], dtype=object),
#   array(['sport', 3.954019704139708], dtype=object)],
#  6)

# %% [markdown]
# #### RidgeCV
# ***
# **Ridge regression** addresses some of the problems of Ordinary Least Squares by imposing a penalty on the size of coefficients. The ridge coefficients minimize a penalized residual sum of squares.

# %%
def max_r_squared_ridge(n):
    rsquared_train = []
    rsquared_test = []
    coeff = []
    # find the maximum r-squared value and corresponding random_state value
    for i in range(n):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=i)
        model = RidgeCV(cv=5, fit_intercept=True).fit(pred_train, tar_train)
        
        rsquared_train.append(model.score(pred_train,tar_train))
        rsquared_test.append(model.score(pred_test,tar_test))
        mx = rsquared_test.index(max(rsquared_test))
        
    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=mx)
    model = RidgeCV(cv=5, fit_intercept=True).fit(pred_train, tar_train)
    predictors_model=pd.DataFrame(listofallpredictors)
    predictors_model.columns = ['label']
    predictors_model['coeff'] = model.coef_
    for index, row in predictors_model.iterrows():
        if row['coeff'] != 0:
            coeff.append(row.values)
    
    return rsquared_train[mx], rsquared_test[mx], coeff, mx, model.intercept_

# %%
max_r_squared_ridge(20000)
# Out:
# (0.8451636872990215,
#  0.8702712392775607,
#  [array(['audienceMaxAge', 0.3726009725147037], dtype=object),
#   array(['audienceMinAge', -0.31392821398146253], dtype=object),
#   array(['budget', 0.2775549322923325], dtype=object),
#   array(['targetingCost', -0.28624748505103526], dtype=object),
#   array(['targetingPercent', -2.894002529856331], dtype=object),
#   array(['placementCost', 0.3348485525148135], dtype=object),
#   array(['ourTargetingPercent', -2.894002529856331], dtype=object),
#   array(['projectedImpressions', -0.011920827892026864], dtype=object),
#   array(['callToAction', 3.0969960702584114], dtype=object),
#   array(['quality', 1.7034252429165346], dtype=object),
#   array(['keywords', 4.035229445189808], dtype=object),
#   array(['contact', -2.668295329389826], dtype=object),
#   array(['CEO', -1.5194100603314573], dtype=object),
#   array(['beautifulFigure', 5.903120340129352], dtype=object),
#   array(['celebrity', -6.77673840265364], dtype=object),
#   array(['targetedStarring', 3.9430222612791157], dtype=object),
#   array(['animated', 1.4214629467269422], dtype=object),
#   array(['bright_colorful', 0.30607051136606667], dtype=object),
#   array(['logoInvolved', 5.571744801750724], dtype=object),
#   array(['mimicUI', 3.7719052996694016], dtype=object),
#   array(['shocking', -7.473532171638734], dtype=object),
#   array(['bgmQuality', 10.792144260958676], dtype=object),
#   array(['eyeCatchingTarget', 5.498817618376716], dtype=object),
#   array(['conversation', -12.061634885163468], dtype=object),
#   array(['wordy', -0.35573129314940566], dtype=object),
#   array(['narratage', 11.742447929432867], dtype=object),
#   array(['textOnly', -1.2219211240359242], dtype=object),
#   array(['eympathy', -11.55051995225313], dtype=object),
#   array(['humor', -3.219393903211511], dtype=object),
#   array(['introduce', 4.73358430489063], dtype=object),
#   array(['accent', -3.206119330559462], dtype=object),
#   array(['suspense', -0.8624157045426689], dtype=object),
#   array(['guarantee', 3.599693664252614], dtype=object),
#   array(['diversity', -3.813973639846921], dtype=object),
#   array(['Australia', 0.31221746164787856], dtype=object),
#   array(['Canada', -7.217875005638012], dtype=object),
#   array(['China', -1.2666226875871704], dtype=object),
#   array(['Costa Rica', -0.5732129642768609], dtype=object),
#   array(['France', -1.087243546641301], dtype=object),
#   array(['Germany', -5.114666646206289], dtype=object),
#   array(['Guyana', 1.5248421534352112], dtype=object),
#   array(['Italy', -0.09631143793247987], dtype=object),
#   array(['Mexico', -2.511093177767616], dtype=object),
#   array(['Monaco', -0.9902386104212048], dtype=object),
#   array(['Nigeria', 1.5248421534352112], dtype=object),
#   array(['Norway', -2.568134302075786], dtype=object),
#   array(['Philippines', -1.2666226875871704], dtype=object),
#   array(['South Korea', -1.2666226875871704], dtype=object),
#   array(['Spain', 2.8924777320664887], dtype=object),
#   array(['Switzerland', 1.4198512392637577], dtype=object),
#   array(['Trinidad and Tabago', -2.347932867390613], dtype=object),
#   array(['Turks and Caicos Island', -2.347932867390613], dtype=object),
#   array(['USA', 0.09361937186580338], dtype=object),
#   array(['United Kingdom', 3.096877964095981], dtype=object),
#   array(['all', 2.5305293927579053], dtype=object),
#   array(['female', -6.120214102807242], dtype=object),
#   array(['male', 3.589684710049336], dtype=object),
#   array([' Campers & Trailers', -0.5691904363796378], dtype=object),
#   array(['$100MM-$200MM', -0.5732129642768609], dtype=object),
#   array(['$10MM-$50MM', -5.2428797925880675], dtype=object),
#   array(['$1B+', -0.5732129642768609], dtype=object),
#   array(['$1MM-$10MM', -5.2428797925880675], dtype=object),
#   array(['$200MM-$1B', -0.5732129642768609], dtype=object),
#   array(['$50MM-$100MM', -5.816092756864929], dtype=object),
#   array(['0-19', 0.500140769589227], dtype=object),
#   array(['0-24', 0.5933215064398418], dtype=object),
#   array(['000', -0.23870529969612142], dtype=object),
#   array(['000+', -0.9896219467187435], dtype=object),
#   array(['000-$199', 1.4312146891397626], dtype=object),
#   array(['000-$299', 1.4312146891397626], dtype=object),
#   array(['000-$499', -1.6699199888358836], dtype=object),
#   array(['000-149', -1.1776745632972867], dtype=object),
#   array(['000-29', 0.500140769589227], dtype=object),
#   array(['000-39', -2.757865587113511], dtype=object),
#   array(['000-49', 0.2364432654651012], dtype=object),
#   array(['000-59', 1.6676579546048633], dtype=object),
#   array(['000-74', -1.53455280427203], dtype=object),
#   array(['000-99', -2.028474844473488], dtype=object),
#   array(['100', -1.1776745632972867], dtype=object),
#   array(['100k149k', -0.721040530929073], dtype=object),
#   array(['150', 0.2421766759664714], dtype=object),
#   array(['20', 0.500140769589227], dtype=object),
#   array(['25', 0.5933215064398418], dtype=object),
#   array(['3-5 Years', -0.4381213661506686], dtype=object),
#   array(['30', -2.757865587113511], dtype=object),
#   array(['40', 0.2364432654651012], dtype=object),
#   array(['50', 1.6676579546048633], dtype=object),
#   array(['50k99k', -0.721040530929073], dtype=object),
#   array(['6-10 Years', -0.5732129642768609], dtype=object),
#   array(['6-9 Years', -0.4381213661506686], dtype=object),
#   array(['60', -1.53455280427203], dtype=object),
#   array(['75', -2.6217963509133293], dtype=object),
#   array(['999', -2.121655581324105], dtype=object),
#   array(['ATVs', -0.5691904363796378], dtype=object),
#   array(['Accounting & Finance', -3.2580063567027384], dtype=object),
#   array(['Administrative', -0.7798100961684089], dtype=object),
#   array(['Advertising', -1.1740508997926007], dtype=object),
#   array(['Agriculture & Manufacturing', 1.172067610869944], dtype=object),
#   array(['Air Travel', -1.2546071931040599], dtype=object),
#   array(['Apparel', -3.3004978766280497], dtype=object),
#   array(['Arts & Entertainment', 2.4331065791116515], dtype=object),
#   array(['Auto Work', 2.9011281157279964], dtype=object),
#   array(['Autos', -12.671096896224284], dtype=object),
#   array(['Back to School', 0.8262501557291204], dtype=object),
#   array(['Bakery', -3.206119330559462], dtype=object),
#   array(['Beauty', -0.9292599665460024], dtype=object),
#   array(['Beverages', 6.145776896222424], dtype=object),
#   array(['Big & Tall', 0.8262501557291204], dtype=object),
#   array(['Blue Collar', -1.8793311448382801], dtype=object),
#   array(['Boating', 5.282613813032375], dtype=object),
#   array(['Books & Literature', -2.6613150389264], dtype=object),
#   array(['Brands', -2.486405815789275], dtype=object),
#   array(['Business', 10.618901696932127], dtype=object),
#   array(['Business & Finance', 3.2056964731999296], dtype=object),
#   array(['Business & Industry', 2.8544536701361434], dtype=object),
#   array(['Business Education', -3.2580063567027384], dtype=object),
#   array(['Business Owner', -2.3949184546866418], dtype=object),
#   array(['Business Travelers', 0.42891913055493636], dtype=object),
#   array(['Camping & Hiking', -2.230652379050666], dtype=object),
#   array(['Cars', 0.8262501557291204], dtype=object),
#   array(['Cell Phones', 0.5933215064398418], dtype=object),
#   array(['Charity & Philanthropy', 14.532019944672355], dtype=object),
#   array(['Childrenâ€™s Apparel', 0.8262501557291204], dtype=object),
#   array(['Clothing', -1.231798622685215], dtype=object),
#   array(['College', -2.6586975749016264], dtype=object),
#   array(['Company Age', -4.131585876773851], dtype=object),
#   array(['Company Sales', -10.220446478702115], dtype=object),
#   array(['Company Size', -4.977566686114046], dtype=object),
#   array(['Computers', 3.4944496221678376], dtype=object),
#   array(['Computers & Technology', -0.5562770452916936], dtype=object),
#   array(['Construction', -0.9300912052516017], dtype=object),
#   array(['Consumer Packaged Goods', 0.5808497970079497], dtype=object),
#   array(['Consumer Services', -4.2541511761732655], dtype=object),
#   array(['Continuing Education', 2.9011281157279964], dtype=object),
#   array(['Cosmetic Surgery', 2.172307570057396], dtype=object),
#   array(['Cosmetics', -0.7417698479978316], dtype=object),
#   array(['Credit & Lending', -0.04615989380747615], dtype=object),
#   array(['Credit Cards', 5.751315320058388], dtype=object),
#   array(['Cruise', -4.817220583568859], dtype=object),
#   array(['Cruises', -0.2931918437562384], dtype=object),
#   array(['Cycling', 2.1485680807495546], dtype=object),
#   array(['DIY', 14.26832244054823], dtype=object),
#   array(['Dating & Romance', -0.09318073685061523], dtype=object),
#   array(['Demographic', 6.227107301047043], dtype=object),
#   array(['Destinations', 0.42891913055493636], dtype=object),
#   array(['Diet & Weight Loss', 2.172307570057396], dtype=object),
#   array(['Dietary Supplements & Nutrition', 0.8496879250516154],
#         dtype=object),
#   array(['Discount Shopping', -0.09318073685061523], dtype=object),
#   array(['Education', -8.860074484666097], dtype=object),
#   array(['Electronics', 2.9011281157279964], dtype=object),
#   array(['Energy & Sports Drinks', 2.7531573670653455], dtype=object),
#   array(['Engineering', 2.9011281157279964], dtype=object),
#   array(['Enrolled', -3.6809382118964047], dtype=object),
#   array(['Environment', -1.4044022233215454], dtype=object),
#   array(['Environmental', -2.230652379050666], dtype=object),
#   array(['Ethnicities', -2.347932867390613], dtype=object),
#   array(['Family & Parenting', 10.680226510335686], dtype=object),
#   array(['Fashion & Style', 11.141675134907212], dtype=object),
#   array(['Finance', 10.412789752314206], dtype=object),
#   array(['Financial Attributes', 2.574615294863184], dtype=object),
#   array(['Fine Dining', 0.8262501557291204], dtype=object),
#   array(['Fishing', -0.4773935095383442], dtype=object),
#   array(['Fishing & Game', 5.282613813032375], dtype=object),
#   array(['Fitness', 0.37324820630451794], dtype=object),
#   array(['Fitness & Exercise', -3.693579410568426], dtype=object),
#   array(['Flights', 0.42891913055493636], dtype=object),
#   array(['Food & Drink', -3.1152333403801813], dtype=object),
#   array(['Fortune 500', -0.5732129642768609], dtype=object),
#   array(['Games', -0.3799354450874799], dtype=object),
#   array(['Gardening', -2.230652379050666], dtype=object),
#   array(['Genres', 0.5933215064398418], dtype=object),
#   array(['Golf', -2.230652379050666], dtype=object),
#   array(['Government', -3.8312193209795993], dtype=object),
#   array(['Graduate School', -3.2520190813414684], dtype=object),
#   array(['Greater Than 10 Years', -0.5732129642768609], dtype=object),
#   array(['Grocery Stores', -5.815693686378569], dtype=object),
#   array(['Handicrafts', -0.3568782409747414], dtype=object),
#   array(['Health', 1.6950404348403083], dtype=object),
#   array(['Health Care', -0.1639039005742161], dtype=object),
#   array(['Healthy Living', 3.9114366889036587], dtype=object),
#   array(['High School', 0.5933215064398418], dtype=object),
#   array(['Hobbies & Leisure', -1.902541641599513], dtype=object),
#   array(['Hockey', -2.397687527499118], dtype=object),
#   array(['Holiday & Seasonal', 0.8262501557291204], dtype=object),
#   array(['Home & Garden', 5.981485470939871], dtype=object),
#   array(['Home Decor', -1.231798622685215], dtype=object),
#   array(['Home Improvement', 2.9011281157279964], dtype=object),
#   array(['Home Owner', -0.4381213661506686], dtype=object),
#   array(['Home Value $100', 1.4312146891397626], dtype=object),
#   array(['Home Value $200', 1.4312146891397626], dtype=object),
#   array(['Home Value $300', -1.6699199888358836], dtype=object),
#   array(['Home Value $500', -1.231798622685215], dtype=object),
#   array(['Home Value less than $100', 1.4312146891397626], dtype=object),
#   array(['Hotels', -2.475369843823498], dtype=object),
#   array(['Hunting/Shooting', -2.230652379050666], dtype=object),
#   array(['In Market', 1.1343653686902018], dtype=object),
#   array(['In Market for', -10.940131185891893], dtype=object),
#   array(['Income', 2.574615294863184], dtype=object),
#   array(['Individual Sports', 5.723178354614462], dtype=object),
#   array(['Industry', -5.066422726952352], dtype=object),
#   array(['Interest', 0.4485463691093545], dtype=object),
#   array(['International Travelers', -2.3418507397453614], dtype=object),
#   array(['Job Hunting', -1.522452903863538], dtype=object),
#   array(['Job Seeker', -1.522452903863538], dtype=object),
#   array(['Large', -0.5732129642768609], dtype=object),
#   array(['Leisure Travelers', -1.2733509713231426], dtype=object),
#   array(['Length of Residence', -0.4381213661506686], dtype=object),
#   array(['Level of Education', -2.6586975749016264], dtype=object),
#   array(['Lifestyle', 5.5486538789647195], dtype=object),
#   array(['Loans', 7.1825300091981505], dtype=object),
#   array(['Low Credit Score', -0.59244282216522], dtype=object),
#   array(['Low Income', -1.522452903863538], dtype=object),
#   array(['Luxury Brand', 0.8262501557291204], dtype=object),
#   array(['Luxury Living', 1.2409724556678423], dtype=object),
#   array(['Management', -3.6809382118964047], dtype=object),
#   array(['Manufacturing', 3.610215048172802], dtype=object),
#   array(['Marital Status', -0.4381213661506686], dtype=object),
#   array(['Mens Apparel', -1.231798622685215], dtype=object),
#   array(['Menâ€™s Apparel', -1.5714373717699974], dtype=object),
#   array(['Menâ€™s Clothing', -2.397687527499118], dtype=object),
#   array(['Military', -3.2580063567027384], dtype=object),
#   array(['Military Wives', -1.522452903863538], dtype=object),
#   array(['Mortgages', 1.4312146891397626], dtype=object),
#   array(['Natural Wellness', -2.2954288530295375], dtype=object),
#   array(['Net Worth', 0.5933215064398418], dtype=object),
#   array(['News', -2.230652379050666], dtype=object),
#   array(['Nutrition', -1.3113903035955436], dtype=object),
#   array(['Occupation', -3.17830589254612], dtype=object),
#   array(['Olympic Sports', -3.206119330559462], dtype=object),
#   array(['Online Activity', 10.719614142321406], dtype=object),
#   array(['Online Games', 0.5933215064398418], dtype=object),
#   array(['Online Shopping', -0.673757396096111], dtype=object),
#   array(['Outdoor & Patio', -2.230652379050666], dtype=object),
#   array(['Outdoor & Recreation', 4.5916069792436245], dtype=object),
#   array(['Outdoor Activities', -1.5349447593482517], dtype=object),
#   array(['Pain Relief', -1.892240100603492], dtype=object),
#   array(['Past Purchasers', -5.104952672876319], dtype=object),
#   array(['Pets & Animals', 8.209474894969695], dtype=object),
#   array(['Photography', -2.230652379050666], dtype=object),
#   array(['Plus Size', 0.8262501557291204], dtype=object),
#   array(['Public', -0.5732129642768609], dtype=object),
#   array(['RVs', -0.5691904363796378], dtype=object),
#   array(['Real Estate', 17.996710429999652], dtype=object),
#   array(['Religion & Inspiration', -0.09318073685061523], dtype=object),
#   array(['Resorts', -2.475369843823498], dtype=object),
#   array(['Restaurants', -2.9631451706212397], dtype=object),
#   array(['Retail', -7.116896097817415], dtype=object),
#   array(['Retail & Shopping', -1.7571767433679304], dtype=object),
#   array(['Retired', -1.522452903863538], dtype=object),
#   array(['Sales & Marketing', -5.691100608051082], dtype=object),
#   array(['Seniors', -1.8222412417086669], dtype=object),
#   array(['Services', -0.8662439666282529], dtype=object),
#   array(['Shoes', -0.42835703737493985], dtype=object),
#   array(['Single', -0.4381213661506686], dtype=object),
#   array(['Single Parent', -1.522452903863538], dtype=object),
#   array(['Small Business', -4.00629898459084], dtype=object),
#   array(['Sporting Goods', -3.206119330559462], dtype=object),
#   array(['Sports', 7.704575680022879], dtype=object),
#   array(['Technical', -1.7290605048580523], dtype=object),
#   array(['Telecommunications', -2.5465323441305032], dtype=object),
#   array(['Theme Park Visitors', -2.475369843823498], dtype=object),
#   array(['Travel', -3.7519290436269523], dtype=object),
#   array(['Trucks', -0.5691904363796378], dtype=object),
#   array(['US Domestic Travelers', -1.2546071931040599], dtype=object),
#   array(['Unemployed', -1.522452903863538], dtype=object),
#   array(['Video Games', -0.3799354450874799], dtype=object),
#   array(['Weather', -2.230652379050666], dtype=object),
#   array(['White Collar', -3.955504817635264], dtype=object),
#   array(['Winter Sports', 3.5746102738649075], dtype=object),
#   array(['Womens Apparel', -1.231798622685215], dtype=object),
#   array(['Womens Interest', -0.09318073685061523], dtype=object),
#   array(['Womenâ€™s Apparel', -1.5714373717699974], dtype=object),
#   array(['Womenâ€™s Clothing', -1.2546071931040599], dtype=object),
#   array(['Woodworking', 2.9011281157279964], dtype=object),
#   array(['Yoga', 0.5808497970079497], dtype=object),
#   array(['Young Adults', -3.4037310490451493], dtype=object),
#   array(['gt150k', -0.721040530929073], dtype=object),
#   array(['apps', 9.145765619654725], dtype=object),
#   array(['in-app', -2.4572861119095997], dtype=object),
#   array(['mobile', -4.9988541106286615], dtype=object),
#   array(['web', 1.3010488191558012], dtype=object),
#   array(['CTR', 4.6914368857654685], dtype=object),
#   array(['reach', -0.9400839769903526], dtype=object),
#   array(['viewability', -3.751352908775118], dtype=object),
#   array(['Airbnb', -0.4887740390945098], dtype=object),
#   array(['Paypal', 5.230444395576943], dtype=object),
#   array(['SEO', 7.086396365199993], dtype=object),
#   array(['auto', -2.0698529336905707], dtype=object),
#   array(['awareness', 12.142799733840427], dtype=object),
#   array(['beauty', -0.04929344807205749], dtype=object),
#   array(['book', -3.2580063567027384], dtype=object),
#   array(['cleaning', -2.714569281819041], dtype=object),
#   array(['cloth', -3.789049496690394], dtype=object),
#   array(['coaching', 2.9011281157279964], dtype=object),
#   array(['company', -6.684895230415585], dtype=object),
#   array(['finiance', -4.720985678132552], dtype=object),
#   array(['food', 9.603497897129222], dtype=object),
#   array(['liquid', -6.164383989604699], dtype=object),
#   array(['park', -1.7022701018780788], dtype=object),
#   array(['price', -2.6088892524370495], dtype=object),
#   array(['product', 1.764859235339264], dtype=object),
#   array(['real estate', -0.4381213661506686], dtype=object),
#   array(['restaurant', -3.132776069452835], dtype=object),
#   array(['senior care', -0.09318073685061523], dtype=object),
#   array(['service', -2.568134302075786], dtype=object),
#   array(['sport', 9.692098228508154], dtype=object),
#   array(['towel', -1.7290605048580523], dtype=object),
#   array(['travel', 0.3326076926224566], dtype=object),
#   array(['unknown', -6.541588876019213], dtype=object)],
#  16559)

# %% [markdown]
# Change the values of alpha to see if anything improves.

# %%
def max_r_squared_ridge_alpha(n):
    global df
    rsquared_train = []
    rsquared_test = []
    df = pd.DataFrame(allvariablenames[1:])
    coeff = []
    # find the maximum r-squared value and corresponding random_state value
    for i in range(n):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=i)
        model = RidgeCV(alphas=[1e-4, 1e-3, 1e-2, 1e-1], cv=5, fit_intercept=True).fit(pred_train, tar_train)
        df["coefficient{0}".format(i)] = model.coef_
        rsquared_train.append(model.score(pred_train,tar_train))
        rsquared_test.append(model.score(pred_test,tar_test))   
        mx = rsquared_test.index(max(rsquared_test))
        
    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=mx)
    model = RidgeCV(alphas=[1e-4, 1e-3, 1e-2, 1e-1], cv=5, fit_intercept=True).fit(pred_train, tar_train)
    predictors_model=pd.DataFrame(listofallpredictors)
    predictors_model.columns = ['label']
    predictors_model['coeff'] = model.coef_
    for index, row in predictors_model.iterrows():
        if row['coeff'] != 0:
            coeff.append(row.values)
    
    return rsquared_train[mx], rsquared_test[mx], mx, model.intercept_

# %%
max_r_squared_ridge_alpha(20000)
# Out:
# (0.9861514268630314, 0.9208814033140389, 18291, 31.726245672450915)

# %% [markdown]
# For RidgeCV model, the best testing $r^2$ is around 0.92. Identifying the top 20 factors.

# %%
## Count the occurrence and sort the factors
df['count'] = df.astype(bool).sum(axis=1)
df = df.sort_values(by=['count'],ascending=False)
df['rank'] = df['count'].rank(ascending=False)
R1 = dfSum[[0,'count','rank']]
R1.head(20)
# Out:
#                           0  count  rank
# 2                    budget  16508   1.0
# 5             placementCost  14894   2.0
# 142  Charity & Philanthropy   7278   3.0
# 3             targetingCost   3478   4.0
# 168                     DIY   2660   5.0
# 293             Real Estate   2655   6.0
# 74                 000-$374   2631   7.0
# 359                  doctor   2189   8.0
# 322           Undergraduate   2150   9.0
# 345                   reach   2088  10.0

# %%
R2 = df[[0,'coefficient18291']].sort_values(by=['coefficient18291'],ascending=False)
R2
# Out:
#                        0  coefficient18291
# 368               school         82.796252
# 322        Undergraduate         81.742635
# 133             Business         66.602421
# 136   Business Education         61.873626
# 187      Fashion & Style         55.973452
# 188              Finance         39.456436
# 359               doctor         39.405445
# 11               contact         36.454750
# 275      Online Activity         35.473239
# 371                sport         34.403980
# 309       Small Business         31.650431
# 344                  CTR         30.920276
# 342               mobile         30.516637
# 163         Credit Cards         29.934758
# 185   Family & Parenting         29.494607
# 247                Loans         28.652892
# 135  Business & Industry         28.313468
# 341               in-app         26.273439
# 100           6-10 Years         24.774452
# 361                 food         24.741795
# 176            Education         24.655860
# 293          Real Estate         24.007103
# 13       beautifulFigure         22.390470
# 215        Home & Garden         22.325386
# 168                  DIY         21.965550
# 347               Airbnb         21.924812
# 303             Services         21.207391
# 50                 Spain         20.040050
# 25             narratage         19.019886
# 126            Beverages         17.466096
# ..                   ...               ...
# 30                accent        -20.542459
# 203             Graduate        -21.025071
# 350                 auto        -21.918553
# 297               Retail        -22.663012
# 231        In Market for        -23.563977
# 164               Cruise        -23.630823
# 58                  male        -24.176633
# 17       bright_colorful        -24.665312
# 255       Marital Status        -25.160627
# 213               Hockey        -25.635014
# 260     Menâ€™s Clothing        -25.635014
# 131   Books & Literature        -26.615548
# 358              company        -26.651838
# 338         Young Adults        -27.126862
# 35                Canada        -29.599140
# 33             diversity        -31.273418
# 43                Mexico        -31.782190
# 272           Occupation        -32.393983
# 27              eympathy        -33.554729
# 318               Travel        -33.754378
# 28                 humor        -33.808577
# 152         Company Size        -34.310123
# 327         White Collar        -40.917738
# 360             finiance        -45.631420
# 23          conversation        -48.925409
# 345                reach        -51.186332
# 343                  web        -53.315937
# 362               liquid        -54.650496
# 110          Advertising        -56.353560
# 151        Company Sales        -56.395556
#
# [377 rows x 2 columns]

# %% [markdown]
# #### ElasticNetCV
# ***
# **ElasticNet** is a linear regression model trained with L1 and L2 prior as regularizer. This combination allows for learning a sparse model where few of the weights are non-zero like Lasso, while still maintaining the regularization properties of Ridge. We control the convex combination of L1 and L2 using the l1_ratio parameter.
# <br>
# Elastic-net is useful when there are multiple features which are correlated with one another. Lasso is likely to pick one of these at random, while elastic-net is likely to pick both.
# <br>
# A practical advantage of trading-off between Lasso and Ridge is it allows Elastic-Net to inherit some of Ridge’s stability under rotation.

# %%
def max_r_squared_elastic(n):
    rsquared_train = []
    rsquared_test = []
    coeff = []
    # find the maximum r-squared value and corresponding random_state value
    for i in range(n):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=i)
        model = ElasticNetCV(cv=5, precompute=False).fit(pred_train, tar_train)
        
        rsquared_train.append(model.score(pred_train,tar_train))
        rsquared_test.append(model.score(pred_test,tar_test))
        mx = rsquared_test.index(max(rsquared_test))
        
    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=mx)
    model = ElasticNetCV(cv=5, precompute=False).fit(pred_train, tar_train)
    predictors_model=pd.DataFrame(listofallpredictors)
    predictors_model.columns = ['label']
    predictors_model['coeff'] = model.coef_
    for index, row in predictors_model.iterrows():
        if row['coeff'] != 0:
            coeff.append(row.values)
    
    return rsquared_train[mx], rsquared_test[mx], coeff, mx, model.intercept_

# %%
max_r_squared_elastic(10000)
# Out:
# (0.42740918548753326,
#  0.9187785455516372,
#  [array(['budget', 0.04110180451316815], dtype=object),
#   array(['projectedImpressions', 0.0045980868175371165], dtype=object)],
#  3302,
#  56.34847246718043)

# %% [markdown]
# #### OrthogonalMatchingPursuitCV
# ***
# **OrthogonalMatchingPursuitCV** Cross-validated Orthogonal Matching Pursuit model (OMP)

# %%
def max_r_squared_elastic(n):
    rsquared_train = []
    rsquared_test = []
    coeff = []
    # find the maximum r-squared value and corresponding random_state value
    for i in range(n):
        pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=i)
        model = OrthogonalMatchingPursuitCV(cv=5).fit(pred_train, tar_train)
        
        rsquared_train.append(model.score(pred_train,tar_train))
        rsquared_test.append(model.score(pred_test,tar_test))
        mx = rsquared_test.index(max(rsquared_test))
        
    pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.3, random_state=mx)
    model = OrthogonalMatchingPursuitCV(cv=5).fit(pred_train, tar_train)
    predictors_model=pd.DataFrame(listofallpredictors)
    predictors_model.columns = ['label']
    predictors_model['coeff'] = model.coef_
    for index, row in predictors_model.iterrows():
        if row['coeff'] != 0:
            coeff.append(row.values)
    
    return rsquared_train[mx], rsquared_test[mx], coeff, mx, model.intercept_

# %%
max_r_squared_elastic(20000)
# Out:
# (0.660064927407843,
#  0.8663663968730866,
#  [array(['placementCost', 0.2873464093549272], dtype=object),
#   array(['mimicUI', 30.610673469836343], dtype=object),
#   array(['000-$374', 129.3121928313342], dtype=object),
#   array(['Company Sales', -54.40228439204767], dtype=object),
#   array(['Family & Parenting', 96.27686563976097], dtype=object),
#   array(['Online Activity', 41.216759348320615], dtype=object),
#   array(['Real Estate', 47.727384807464496], dtype=object),
#   array(['reach', -54.10834679843333], dtype=object),
#   array(['doctor', 132.66656983428442], dtype=object)],
#  16230,
#  28.443466139931346)

# %% [markdown]
# The optimal $r^2$ in this model is good, but the difference betweeen these two $r-squared$ makes it inconsistent.
